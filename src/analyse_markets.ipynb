# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("../data/active_markets.jsonl", lines=True)

# %%
df.head()
# Out:
#         id                                           question  \
# 0  2036399    US x Iran ceasefire extended by April 22, 2026?
# 1   669661  Will the Fed decrease interest rates by 25 bps...
# 2   669662  Will there be no change in Fed interest rates ...
# 3   573655           Will Bitcoin hit $150k by June 30, 2026?
# 4  2037907                      Clavicular pregnancy in 2026?
#
#                                          conditionId  \
# 0  0x1d2787cb8aed975d092b2799ed6f4083e9445f7420cd...
# 1  0x0d14f5dc9fb3250ec888b1ac8d9fe9a0ce06f9d3ea60...
# 2  0x36e8ca24d2a13435f519f15580d42b45cdbe3bc425fb...
# 3  0xa0f4c4924ea1a8b410b4ce821c2a9955fad21a1b19bd...
# 4  0x6747bae2269c348786d0c0c0f4286ac006f13f16325d...
#
#                                                 slug resolutionSource  \
# 0      us-x-iran-ceasefire-extended-by-april-22-2026
# 1  will-the-fed-decrease-interest-rates-by-25-bps...              NaN
# 2  will-there-be-no-change-in-fed-interest-rates-...              NaN
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'question',
#  'conditionId',
#  'slug',
#  'resolutionSource',
#  'endDate',
#  'liquidity',
#  'startDate',
#  'image',
#  'icon',
#  'description',
#  'outcomes',
#  'outcomePrices',
#  'volume',
#  'active',
#  'closed',
#  'marketMakerAddress',
#  'createdAt',
#  'updatedAt',
#  'new',
#  'featured',
#  'submitted_by',
#  'archived',
#  'resolvedBy',
#  'restricted',
#  'groupItemTitle',
#  'groupItemThreshold',
#  'questionID',
#  'enableOrderBook',
#  'orderPriceMinTickSize',
#  'orderMinSize',
#  'umaResolutionStatus',
#  'volumeNum',
#  'liquidityNum',
#  'endDateIso',
#  'startDateIso',
#  'hasReviewedDates',
#  'volume24hr',
#  'volume1wk',
#  'volume1mo',
#  'volume1yr',
#  'clobTokenIds',
#  'umaBond',
#  'umaReward',
#  'volume24hrClob',
#  'volume1wkClob',
#  'volume1moClob',
#  'volume1yrClob',
#  'volumeClob',
#  'liquidityClob',
#  'customLiveness',
#  'acceptingOrders',
#  'negRisk',
#  'negRiskRequestID',
#  'events',
#  'ready',
#  'funded',
# ...

# %%
res = df[["volume24hr"]].value_counts().reset_index()
res = res.sort_values(by="volume24hr", ascending=False)
print(len(df))
print(len(df[df["volume24hr"] > 1000]))
# Out:
# 44681
# 3105

# %%
res = flat.loc[flat["volume24hr"] != 0]

# %%
print(res.shape)
print(flat.shape)
# Out:
# (47076, 111)
# (47176, 111)

# %%
import json

top_100_ids = flat.iloc[:100]
mid_100_ids = flat.iloc[100:200]
print(top_100_ids.iloc[:2]['clobTokenIds'].to_list())

json.loads(value)
# Out:
# ['["50049642142024617231697970377792489304039200104142714216386619263735691638204", "110959653450933276250915064669875552310439627880508793089816880777942697720191"]', '["13915689317269078219168496739008737517740566192006337297676041270492637394586", "13290642914521189871602119663452054126359842904805799115978921503195267156991"]']
